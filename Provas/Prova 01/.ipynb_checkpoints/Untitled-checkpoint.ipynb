# %% [markdown]
# # Avaliação Parcial 01 - Mineração de Dados
# ---------

# %% [markdown]
# ## Francisco Wesley Pedro Lima
# ### 398261
# ------------

# %% [markdown]
# ## Questão 01

# %%
# Importação das bibliotecas

import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('wine_ap1.csv')

# %%
dataframe.head()
# Out:
#    Unnamed: 0  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0           0    14.23        1.71  2.43               15.6      127.0
# 1           1    13.20        1.78  2.14               11.2      100.0
# 2           2    13.16        2.36  2.67               18.6      101.0
# 3           3    14.37        1.95  2.50               16.8      113.0
# 4           4    13.24         NaN   NaN               21.0      118.0
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    color_intensity   hue  od280/od315_of_diluted_wines  proline  y
# ...

# %%
dataframe.isnull().sum()
# Out:
# Unnamed: 0                       0
# alcohol                          9
# malic_acid                      11
# ash                              6
# alcalinity_of_ash                9
# magnesium                       13
# total_phenols                    9
# flavanoids                      13
# nonflavanoid_phenols            13
# proanthocyanins                 11
# color_intensity                  7
# hue                             13
# od280/od315_of_diluted_wines     6
# proline                          8
# y                                0
# dtype: int64

# %%
dataframe.fillna(dataframe.mean(), inplace=True)

# %%
df = pd.DataFrame(dataframe)

# %%
df.drop(labels=[0])
# Out:
#      Unnamed: 0    alcohol  malic_acid       ash  alcalinity_of_ash  \
# 1             1  13.200000    1.780000  2.140000          11.200000
# 2             2  13.160000    2.360000  2.670000          18.600000
# 3             3  14.370000    1.950000  2.500000          16.800000
# 4             4  13.240000    2.345569  2.368837          21.000000
# 5             5  14.200000    1.760000  2.450000          15.200000
# 6             6  14.390000    1.870000  2.368837          14.600000
# 7             7  14.060000    2.150000  2.610000          17.600000
# 8             8  14.830000    1.640000  2.170000          14.000000
# 9             9  13.860000    1.350000  2.270000          16.000000
# 10           10  14.100000    2.160000  2.300000          18.000000
# 11           11  14.120000    1.480000  2.320000          16.800000
# 12           12  13.750000    1.730000  2.410000          16.000000
# 13           13  14.750000    1.730000  2.390000          11.400000
# ...

# %%
df.drop([0], axis=0)
# Out:
#      Unnamed: 0    alcohol  malic_acid       ash  alcalinity_of_ash  \
# 1             1  13.200000    1.780000  2.140000          11.200000
# 2             2  13.160000    2.360000  2.670000          18.600000
# 3             3  14.370000    1.950000  2.500000          16.800000
# 4             4  13.240000    2.345569  2.368837          21.000000
# 5             5  14.200000    1.760000  2.450000          15.200000
# 6             6  14.390000    1.870000  2.368837          14.600000
# 7             7  14.060000    2.150000  2.610000          17.600000
# 8             8  14.830000    1.640000  2.170000          14.000000
# 9             9  13.860000    1.350000  2.270000          16.000000
# 10           10  14.100000    2.160000  2.300000          18.000000
# 11           11  14.120000    1.480000  2.320000          16.800000
# 12           12  13.750000    1.730000  2.410000          16.000000
# 13           13  14.750000    1.730000  2.390000          11.400000
# ...

# %% [markdown]
# ## Questão 02

# %%
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import NearestNeighbors

# %%
dt = np.array(dataframe)

# %%
X = dt[:-1]
y = dt[-1]

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.25, random_state=True, )

# %%
clf1 = DecisionTreeClassifier(max_depth=4)
clf2 = KNeighborsClassifier(n_neighbors=7)
